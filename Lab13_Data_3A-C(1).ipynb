# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

D1 = pd.read_csv('Loc1_session1_group1_2024-04-10_16-06-56.csv') 
D2 = pd.read_csv('Loc1_session2_group1_2024-04-10_16-18-39.csv') 
D3 = pd.read_csv('Loc1_session3_group1_2024-04-10_16-28-32.csv')

# %%
def Graphing(D,str1,str2):
    plt.plot(D)
    plt.title(str1 + ' vs Time ' + str2)
    plt.xlabel('Time')
    plt.ylabel(str1)
    plt.show()
    
    plt.hist(D)
    plt.title('Distribution of ' + str1+' '+str2)
    plt.xlabel(str1)
    plt.ylabel('Frequency')
    plt.show()
    
    Mean = np.mean(D)
    STD = np.std(D)
    CSTD = np.sqrt(Mean)
    RatioS = STD/CSTD
    
    print('The mean is',Mean)
    print('The STD is', STD)
    print('The STD using the mean as the expected counts is',CSTD)
    print('The ratio of the actual STD over counting statistics STD is', RatioS)

# %%
Graphing(D1['counts'],'Counts','Jacobs Hall')
# Out:
# The mean is 40.97115384615385
# The STD is 4.880376845676832
# The STD using the mean as the expected counts is 6.400871334916352
# The ratio of the actual STD over counting statistics STD is 0.762455076866595

# %%
Graphing(D1['Temperature'],'Temperature','Jacobs Hall')
# Out:
# The mean is 24.04308781550481
# The STD is 0.09391978057531335
# The STD using the mean as the expected counts is 4.90337514529582
# The ratio of the actual STD over counting statistics STD is 0.019154108709266864

# %%
Graphing(D1['Humidity'],'Humidity','Jacobs Hall')
# Out:
# The mean is 45.98331235121874
# The STD is 0.38863440960896617
# The STD using the mean as the expected counts is 6.781099641740913
# The ratio of the actual STD over counting statistics STD is 0.057311414098199565

# %%
Graphing(D2['counts'],'Counts','Cory Hall')
# Out:
# The mean is 38.14117647058824
# The STD is 2.336175563388972
# The STD using the mean as the expected counts is 6.175854310991172
# The ratio of the actual STD over counting statistics STD is 0.3782756920336153

# %%
Graphing(D2['Temperature'],'Temperature','Cory Hall')
# Out:
# The mean is 25.208740234375
# The STD is 0.3511846853759051
# The STD using the mean as the expected counts is 5.020830631914903
# The ratio of the actual STD over counting statistics STD is 0.06994553513587974

# %%
Graphing(D2['Humidity'],'Humidity','Cory Hall')
# Out:
# The mean is 44.20156779335297
# The STD is 1.0210159527979803
# The STD using the mean as the expected counts is 6.648425963591155
# The ratio of the actual STD over counting statistics STD is 0.1535725837046815

# %%
Graphing(D3['counts'],'Counts','Bechtel Hall')
# Out:
# The mean is 29.921621621621625
# The STD is 2.2717578781264964
# The STD using the mean as the expected counts is 5.470065961359299
# The ratio of the actual STD over counting statistics STD is 0.41530721826286165

# %%
Graphing(D3['Temperature'],'Temperature','Bechtel Hall')
# Out:
# The mean is 26.537213365709462
# The STD is 0.258134639730156
# The STD using the mean as the expected counts is 5.151428284049916
# The ratio of the actual STD over counting statistics STD is 0.050109333857835905

# %%
Graphing(D3['Humidity'],'Humidity','Bechtel Hall')
# Out:
# The mean is 41.30998174889519
# The STD is 0.3734917429871839
# The STD using the mean as the expected counts is 6.427284165874043
# The ratio of the actual STD over counting statistics STD is 0.05811035164280666
