# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
df2 = pd.read_csv("lab4outside.csv")
df1 = pd.read_csv("outsidedata.csv")
new_data = df1.loc[:,"Time":"Gas"]
new_data2 = df2.loc[:,"Time":"Gas"]

# %%
plt.hist(new_data["PM25"][30:], label="new_data") #bl
plt.hist(new_data2["pm25"][30:], label="new_data2") #or
plt.title("Time vs Pm25")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["PM10"][30:], label="new_data")
plt.hist(new_data2["pm10"][30:], label="new_data2")
plt.title("Time vs Pm10")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Temperature"][30:], label="new_data")
plt.hist(new_data2["Temperature"][30:], label="new_data2")
plt.title("Time vs Temperature")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Pressure"][30:], label="new_data")
plt.hist(new_data2["Pressure"][30:], label="new_data")
plt.title("Time vs Pressure")
plt.legend
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pressure'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.hist(new_data["Humidity"][30:], label="new_data")
plt.hist(new_data2["Humidity"][30:], label="new_data")
plt.title("Time vs Humidity")
plt.legend
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Humidity'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.hist(new_data["Altitude"][30:], label="new_data")
plt.hist(new_data2["Altitude"][30:], label="new_data2")
plt.title("Time vs Altitude")
plt.legend
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Altitude'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.hist(new_data["Gas"][30:], label="new_data")
plt.hist(new_data2["Gas"][30:], label="new_data")
plt.title("Time vs Gas")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
