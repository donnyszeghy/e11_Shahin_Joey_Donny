# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
D1 = pd.read_csv('file1.csv') 
D2 = pd.read_csv('file2.csv') 
D3 = pd.read_csv('file3.csv')
D4 = pd.read_csv('file4.csv') 
D5 = pd.read_csv('file5.csv') 
D6 = pd.read_csv('file6.csv')
D7 = pd.read_csv('file7.csv') 
D8 = pd.read_csv('file8.csv') 
D9 = pd.read_csv('file9.csv')
D10 = pd.read_csv('file10.csv') 
D11 = pd.read_csv('file11.csv') 
D12 = pd.read_csv('file12.csv')
D13 = pd.read_csv('file13.csv') 
D14 = pd.read_csv('file14.csv') 
D15 = pd.read_csv('file15.csv')
D16 = pd.read_csv('file16.csv') 
D17 = pd.read_csv('file17.csv') 
D18 = pd.read_csv('file18.csv')
D19 = pd.read_csv('file19.csv') 
D20 = pd.read_csv('file20.csv') 
D21 = pd.read_csv('file21.csv')
D22 = pd.read_csv('file22.csv') 
D23 = pd.read_csv('file23.csv') 
D24 = pd.read_csv('file24.csv')
D25 = pd.read_csv('file25.csv') 
D26 = pd.read_csv('file26.csv') 
D27 = pd.read_csv('file27.csv')
D28 = pd.read_csv('file28.csv') 
D29 = pd.read_csv('file29.csv') 
D30 = pd.read_csv('file30.csv')
D31 = pd.read_csv('file31.csv')
D32 = pd.read_csv('file32.csv') 
D33 = pd.read_csv('file33.csv') 
D34 = pd.read_csv('file34.csv')

# %%
D1['co2']
# Out:
# 0      244.493378
# 1      324.210175
# 2      521.394165
# 3      497.401001
# 4      488.444824
#           ...
# 102           NaN
# 103           NaN
# 104           NaN
# 105           NaN
# 106           NaN
# Name: co2, Length: 107, dtype: float64

# %%
import pandas as pd
MCN1 = np.mean(D1['counts'])
MCN2 = np.mean(D2['counts'])
MCN3 = np.mean(D3['counts'])
MCN4 = np.mean(D4['counts'])
MCN5 = np.mean(D5['counts'])
MCN16 = np.mean(D16['counts'])
MCN17 = np.mean(D17['counts'])
MCN18 = np.mean(D18['counts'])
MCN19 = np.mean(D19['counts'])
MCN20 = np.mean(D20['counts'])
MAN1 = np.mean(D1['altitude'])
MAN2 = np.mean(D2['altitude'])
MAN3 = np.mean(D3['altitude'])
MAN4 = np.mean(D4['altitude'])
MAN5 = np.mean(D5['altitude'])
MAN16 = np.mean(D16['altitude'])
MAN17 = np.mean(D17['altitude'])
MAN18 = np.mean(D18['altitude'])
MAN19 = np.mean(D19['altitude'])
MAN20 = np.mean(D20['altitude'])
MON1 = np.mean(D1['co2'])
MON2 = np.mean(D2['co2'])
MON3 = np.mean(D3['co2'])
MON4 = np.mean(D4['co2'])
MON5 = np.mean(D5['co2'])
MON16 = np.mean(D16['co2'])
MON17 = np.mean(D17['co2'])
MON18 = np.mean(D18['co2'])
MON19 = np.mean(D19['co2'])
MON20 = np.mean(D20['co2'])
N_counts = [MCN1,MCN2,MCN3,MCN4,MCN5,MCN16,MCN17,MCN18,MCN19,MCN20]
N_altitude = [MAN1,MAN2,MAN3,MAN4,MAN5,MAN16,MAN17,MAN18,MAN19,MAN20]
N_co2 = [MON1,MON2,MON3,MON4,MON5,MON16,MON17,MON18,MON19,MON20]

# %%
MCM1 = np.mean(D6['counts'])
MCM2 = np.mean(D7['counts'])
MCM3 = np.mean(D8['counts'])
MCM4 = np.mean(D9['counts'])
MCM5 = np.mean(D10['counts'])
MCM21 = np.mean(D29['counts'])
MCM22 = np.mean(D22['counts'])
MCM23 = np.mean(D23['counts'])
MCM24 = np.mean(D24['counts'])
MCM25 = np.mean(D25['counts'])
MAM1 = np.mean(D6['altitude'])
MAM2 = np.mean(D7['altitude'])
MAM3 = np.mean(D8['altitude'])
MAM4 = np.mean(D9['altitude'])
MAM5 = np.mean(D10['altitude'])
MAM21 = np.mean(D29['altitude'])
MAM22 = np.mean(D22['altitude'])
MAM23 = np.mean(D23['altitude'])
MAM24 = np.mean(D24['altitude'])
MAM25 = np.mean(D25['altitude'])
MOM1 = np.mean(D6['co2'])
MOM2 = np.mean(D7['co2'])
MOM3 = np.mean(D8['co2'])
MOM4 = np.mean(D9['co2'])
MOM5 = np.mean(D10['co2'])
MOM21 = np.mean(D29['co2'])
MOM22 = np.mean(D22['co2'])
MOM23 = np.mean(D23['co2'])
MOM24 = np.mean(D24['co2'])
MOM25 = np.mean(D25['co2'])
M_counts = [MCM1,MCM2,MCM3,MCM4,MCM5,MCM21,MCM22,MCM23,MCM24,MCM25]
M_altitude = [MAM1,MAM2,MAM3,MAM4,MAM5,MAM21,MAM22,MAM23,MAM24,MAM25]
M_co2 = [MOM1,MOM2,MOM3,MOM4,MOM5,MOM21,MOM22,MOM23,MOM24,MOM25]

# %%
MCS1 = np.mean(D11['counts'])
MCS2 = np.mean(D12['counts'])
MCS3 = np.mean(D13['counts'])
MCS4 = np.mean(D14['counts'])
MCS5 = np.mean(D15['counts'])
MCS30 = np.mean(D30['counts'])
MCS31 = np.mean(D31['counts'])
MCS32 = np.mean(D32['counts'])
MCS33 = np.mean(D33['counts'])
MCS34 = np.mean(D34['counts'])
MAS1 = np.mean(D11['altitude'])
MAS2 = np.mean(D12['altitude'])
MAS3 = np.mean(D13['altitude'])
MAS4 = np.mean(D14['altitude'])
MAS5 = np.mean(D15['altitude'])
MAS30 = np.mean(D30['altitude'])
MAS31 = np.mean(D31['altitude'])
MAS32 = np.mean(D32['altitude'])
MAS33 = np.mean(D33['altitude'])
MAS34 = np.mean(D34['altitude'])
MOS1 = np.mean(D11['co2'])
MOS2 = np.mean(D12['co2'])
MOS3 = np.mean(D13['co2'])
MOS4 = np.mean(D14['co2'])
MOS5 = np.mean(D15['co2'])
MOS30 = np.mean(D30['co2'])
MOS31 = np.mean(D31['co2'])
MOS32 = np.mean(D32['co2'])
MOS33 = np.mean(D33['co2'])
MOS34 = np.mean(D34['co2'])
S_counts = [MCS1,MCS2,MCS3,MCS4,MCS5,MCS30,MCS31,MCS32,MCS33,MCS34]
S_altitude = [MAS1,MAS2,MAS3,MAS4,MAS5,MAS30,MAS31,MAS32,MAS33,MAS34]
S_co2 = [MOS1,MOS2,MOS3,MOS4,MOS5,MOS30,MOS31,MOS32,MOS33,MOS34]

# %%
def Graphing(x_data1, y_data1, x_data2, y_data2, x_data3, y_data3, x_label, y_label, title,):
    plt.figure(figsize=(10, 6))  # Creates a new figure with a specified size
    plt.plot(x_data1, y_data1, marker='o', label='N Series')  # Plot first series
    plt.plot(x_data2, y_data2, marker='x', label='M Series')  # Plot second series
    plt.plot(x_data3, y_data3, marker='^', label='S Series')  # Plot third series
    plt.title(title)  # Set the title of the graph
    plt.xlabel(x_label)  # Set the label for the x-axis
    plt.ylabel(y_label)  # Set the label for the y-axis
    plt.legend()  # Display legend
    plt.grid(True)  # Enable grid
    plt.show()
 



# Now, call the Graphing functio
Graphing(N_altitude, N_counts, M_altitude, M_counts, S_altitude, S_counts, 'Altitude (meters)', 'Counts', 'Counts vs Altitude Comparison')

# %%
Graphing(N_co2, N_counts, M_co2, M_counts, S_co2, S_counts, 'co2 (PPM)', 'Counts', 'Counts vs co2 Comparison')

# %%
Graphing(N_altitude, N_co2, M_altitude, M_co2, S_altitude, S_co2, 'altitude', 'co2 (PPM)', 'altitude vs co2 Comparison')

# %%
# Out:
# 0     432.449219
# 1     369.988831
# 2     362.730133
# 3     418.646667
# 4     373.776672
#          ...
# 83    450.354706
# 84    898.736389
# 85    756.764771
# 86    724.895142
# 87    587.592712
# Name: co2, Length: 88, dtype: float64
