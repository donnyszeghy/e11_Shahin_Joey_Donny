# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
df2 = pd.read_csv("lab4outside.csv") #our data
df1 = pd.read_csv("outsidedata.csv") #other groups data
new_data = df1 
new_data2 = df2
us = 'Our Data'
them = "Other Group's Data"

# %%
plt.hist(new_data["PM25"][30:], label = them ) #bl
plt.hist(new_data2["pm25"][30:], label = us ) #or
plt.title("Pm25")
plt.legend()
plt.show ()

# %%
plt.hist(new_data["PM10"][30:], label=them)
plt.hist(new_data2["pm10"][30:], label=us)
plt.title("Pm10")
plt.legend()
plt.show()

# %%
plt.hist(new_data["Temperature"][30:], label=them)
plt.hist(new_data2["Temperature"][30:], label=us)
plt.title("Temperature")
plt.legend()
plt.show()

# %%
plt.hist(new_data["Pressure"][30:], label=them)
plt.hist(new_data2["Pressure"][30:], label=us)
plt.title("Pressure")
plt.legend()
plt.show()

# %%
plt.hist(new_data["Humidity"][30:], label=them)
plt.hist(new_data2["Humidity"][30:], label=us)
plt.title("Humidity")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Altitude"][30:], label=them)
plt.hist(new_data2["Altitude"][30:], label=us)
plt.title("Altitude")
plt.legend()
plt.show()

# %%
plt.hist(new_data["Gas"][30:], label=them)
plt.hist(new_data2["Gas"][30:], label=us)
plt.title("Gas")
plt.legend()
plt.show()
