# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
df1 = pd.read_csv("lab4inside.csv")
df2 = pd.read_csv("lab4outside.csv")
new_data = df1.loc[:,"Time":"Gas"]
new_data2 = df2.loc[:,"Time":"Gas"]

# %%
plt.plot(new_data["pm25"])
plt.plot(new_data2["pm25"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["pm10"])
plt.plot(new_data2["pm10"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["Temperature"])
plt.plot(new_data2["Temperature"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["Pressure"])
plt.plot(new_data2["Pressure"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["Humidity"])
plt.plot(new_data2["Humidity"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["Altitude"])
plt.plot(new_data2["Altitude"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(new_data["Gas"])
plt.plot(new_data2["Gas"])
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["pm25"])
plt.hist(new_data2["pm25"])
plt.title("Time vs Pm25")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["pm10"])
plt.hist(new_data2["pm10"])
plt.title("Time vs Pm10")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Temperature"])
plt.hist(new_data2["Temperature"])
plt.title("Time vs Temperature")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Pressure"])
plt.hist(new_data2["Pressure"])
plt.title("Time vs Pressure")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Humidity"])
plt.hist(new_data2["Humidity"])
plt.title("Time vs Humidity")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Altitude"])
plt.hist(new_data2["Altitude"])
plt.title("Time vs Altitude")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(new_data["Gas"])
plt.hist(new_data2["Gas"])
plt.title("Time vs Gas")
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mean_inside = np.mean(new_data["Gas"])
mean_outside = np.mean(new_data2["Gas"])

# %%
std_mean_inside = np.std(new_data["Gas"])
x1 = np.std(new_data2["Gas"])

# %%
#x - 3sigma_mean vs regular mean of other
# Out:
# 125191.22473512402

# %%
# Out:
# 34658.13553423625
